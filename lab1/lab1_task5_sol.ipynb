# %%
import matplotlib.pyplot as plt
import numpy as np

img = plt.imread('./requirements/masoleh_gray.jpg')

# %%
img2 = np.vstack([img, img[::-1, :]])

# %%
plt.figure(figsize=(8, 8))
plt.imshow(img2, cmap='gray')
plt.show()
